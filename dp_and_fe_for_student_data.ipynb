# %% [markdown]
# # **650710862 ชนกันต์ กิตติวิริยะ**

# %%
import pandas as pd
import numpy as np

# %%
df_student = pd.read_csv('student_data.csv')

# %% [markdown]
# # เช็คข้อมูล 🔃

# %%
df_student
# Out:
#     รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2          64003       NaN    NaN    Male         Science  3.67       175.0
# 3          64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5          64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6          64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9          64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    NaN     NaN             NaN  3.78         NaN
# ...

# %% [markdown]
# # เปลี่ยนชื่อคนที่เป็น NaN ให้เป็น 'ไม่ระบุ📜'

# %%
df_student['ชื่อ'].fillna('ไม่ระบุ', inplace=True)
# Out:
# /tmp/ipython-input-3051647487.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_student['ชื่อ'].fillna('ไม่ระบุ', inplace=True)

# %%
df_student
# Out:
#     รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2          64003   ไม่ระบุ    NaN    Male         Science  3.67       175.0
# 3          64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5          64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6          64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9          64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    NaN     NaN             NaN  3.78         NaN
# ...

# %% [markdown]
# # **จัดการกับคนที่อายุเป็น NaN ให้เป็น ค่ากลางของคนทั้งหมด 📊**
# # **จัดการกับคนที่อายุผิดปกติ** 100++ ปี**

# %%
df_student['อายุ'].fillna(df_student['อายุ'].median(), inplace=True)

# คำนวณ IQR (Interquartile Range)
Q1 = df_student['อายุ'].quantile(0.25)
Q3 = df_student['อายุ'].quantile(0.75)
IQR = Q3 - Q1

# สร้างขอบเขตสำหรับ outlier
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# กรองข้อมูลที่อยู่นอกช่วง (เอาเฉพาะที่ไม่ใช่ outlier)
df_student = df_student[(df_student['อายุ'] >= lower_bound) & (df_student['อายุ'] <= upper_bound)]
# Out:
# /tmp/ipython-input-520906506.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_student['อายุ'].fillna(df_student['อายุ'].median(), inplace=True)

# %%
df_student
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย  20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง  21.0    หญิง           วิทย์  3.45       165.0
# 2          64003   ไม่ระบุ  21.0    Male         Science  3.67       175.0
# 3          64004  สมศักดิ์  22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ  19.0       ญ           วิศวะ  3.89       160.0
# 6          64007     กิตติ  21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา  20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป  23.0       M            Arts  3.34       163.0
# 9          64010      ดารา  21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ  21.0     NaN             NaN  3.78         NaN
# 11         64012       นภา  22.0     ชาย           วิทย์   NaN       171.0
# ...

# %% [markdown]
# # **ทำให้เพศและชื่อคณะเป็นมาตรฐาน🚹🚺&📝**

# %%
gender_mapping = {
    'ช': 'ชาย',
    'ชาย': 'ชาย',
    'M': 'ชาย',
    'Male': 'ชาย',

    'ญ': 'หญิง',
    'หญิง': 'หญิง',
    'F': 'หญิง',
    'Female': 'หญิง'
}
df_student['เพศ'] = df_student['เพศ'].map(gender_mapping)
df_student['เพศ'].fillna(df_student['เพศ'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-2950894451.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_student['เพศ'] = df_student['เพศ'].map(gender_mapping)
# /tmp/ipython-input-2950894451.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
faculty_mapping = {
    'วิทย์': 'วิทยาศาสตร์',
    'คณะวิทยาศาสตร์': 'วิทยาศาสตร์',
    'Science': 'วิทยาศาสตร์',
    'Sci': 'วิทยาศาสตร์',
    'วิทยาศาสตร์': 'วิทยาศาสตร์',

    'วิศวะ': 'วิศวกรรมศาสตร์',
    'วิศวฯ': 'วิศวกรรมศาสตร์',
    'วิศวกรรม': 'วิศวกรรมศาสตร์',
    'Engineering': 'วิศวกรรมศาสตร์',
    'วิศวกรรมศาสตร์': 'วิศวกรรมศาสตร์',

    'ศิลป์': 'ศิลปศาสตร์',
    'Arts': 'ศิลปศาสตร์',
    'Liberal Arts': 'ศิลปศาสตร์',
    'ศิลปศาสตร์': 'ศิลปศาสตร์'
}
df_student['คณะ'] = df_student['คณะ'].map(faculty_mapping)


most_common_faculty = df_student['คณะ'].mode()[0]
df_student['คณะ'].fillna(most_common_faculty, inplace=True)
# Out:
# /tmp/ipython-input-448310377.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_student['คณะ'] = df_student['คณะ'].map(faculty_mapping)
# /tmp/ipython-input-448310377.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
df_student
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง  21.0  หญิง     วิทยาศาสตร์  3.45       165.0
# 2          64003   ไม่ระบุ  21.0   ชาย     วิทยาศาสตร์  3.67       175.0
# 3          64004  สมศักดิ์  22.0   ชาย     วิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ  19.0  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ  21.0  หญิง  วิศวกรรมศาสตร์  4.50       158.0
# 7          64008      จิรา  20.0  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป  23.0   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา  21.0  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ  21.0  หญิง     วิทยาศาสตร์  3.78         NaN
# 11         64012       นภา  22.0   ชาย     วิทยาศาสตร์   NaN       171.0
# 12         64013     บุญมี  20.0  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# ...

# %% [markdown]
# # แก้ไข GPA ผิดปกติ✍️

# %%
df_student.loc[df_student['GPA'] < 0, 'GPA'] = np.nan
df_student.loc[df_student['GPA'] > 4, 'GPA'] = 4.0
mean_gpa = df_student['GPA'].mean()
df_student['GPA'].fillna(mean_gpa, inplace=True)
# Out:
# /tmp/ipython-input-2853611254.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_student['GPA'].fillna(mean_gpa, inplace=True)
# /tmp/ipython-input-2853611254.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_student['GPA'].fillna(mean_gpa, inplace=True)

# %%
df_student
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ       GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.210000       170.0
# 1          64002    สมหญิง  21.0  หญิง     วิทยาศาสตร์  3.450000       165.0
# 2          64003   ไม่ระบุ  21.0   ชาย     วิทยาศาสตร์  3.670000       175.0
# 3          64004  สมศักดิ์  22.0   ชาย     วิทยาศาสตร์  3.488125       168.0
# 4          64005      สมใจ  19.0  หญิง  วิศวกรรมศาสตร์  3.890000       160.0
# 6          64007     กิตติ  21.0  หญิง  วิศวกรรมศาสตร์  4.000000       158.0
# 7          64008      จิรา  20.0  หญิง      ศิลปศาสตร์  2.980000       180.0
# 8          64009    ชนาธิป  23.0   ชาย      ศิลปศาสตร์  3.340000       163.0
# 9          64010      ดารา  21.0  หญิง      ศิลปศาสตร์  3.560000       167.0
# 10         64011      ธีระ  21.0  หญิง     วิทยาศาสตร์  3.780000         NaN
# 11         64012       นภา  22.0   ชาย     วิทยาศาสตร์  3.488125       171.0
# ...

# %% [markdown]
# # แก้ไขส่วนสูง น้ำหนักและชั่วโมงเรียน ที่ผิดปกติ ✏️

# %%
num_cols = [ 'น้ำหนัก_kg', 'ส่วนสูง_cm',]
for col in num_cols:
    df_student[col].fillna(df_student[col].median(), inplace=True)
df_student.rename(columns={
    'น้ำหนัก_kg' : 'น้ำหนัก(kg)',

    'ส่วนสูง_cm': 'ส่วนสูง(cm)'
}, inplace=True)
# Out:
# /tmp/ipython-input-2059861588.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_student[col].fillna(df_student[col].median(), inplace=True)
# /tmp/ipython-input-2059861588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_student[col].fillna(df_student[col].median(), inplace=True)
# ...

# %%
df_student
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ       GPA  ส่วนสูง(cm)  \
# 0          64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.210000        170.0
# 1          64002    สมหญิง  21.0  หญิง     วิทยาศาสตร์  3.450000        165.0
# 2          64003   ไม่ระบุ  21.0   ชาย     วิทยาศาสตร์  3.670000        175.0
# 3          64004  สมศักดิ์  22.0   ชาย     วิทยาศาสตร์  3.488125        168.0
# 4          64005      สมใจ  19.0  หญิง  วิศวกรรมศาสตร์  3.890000        160.0
# 6          64007     กิตติ  21.0  หญิง  วิศวกรรมศาสตร์  4.000000        158.0
# 7          64008      จิรา  20.0  หญิง      ศิลปศาสตร์  2.980000        180.0
# 8          64009    ชนาธิป  23.0   ชาย      ศิลปศาสตร์  3.340000        163.0
# 9          64010      ดารา  21.0  หญิง      ศิลปศาสตร์  3.560000        167.0
# 10         64011      ธีระ  21.0  หญิง     วิทยาศาสตร์  3.780000        167.5
# 11         64012       นภา  22.0   ชาย     วิทยาศาสตร์  3.488125        171.0
# ...

# %% [markdown]
# # **แก้ไขชั่วโมงเรียนต่อสัปดาห์📚**

# %%
df_student["ชั่วโมงเรียน_ต่อสัปดาห์"].fillna(df_student['ชั่วโมงเรียน_ต่อสัปดาห์'].median() , inplace=True)
# Out:
# /tmp/ipython-input-3580748940.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_student["ชั่วโมงเรียน_ต่อสัปดาห์"].fillna(df_student['ชั่วโมงเรียน_ต่อสัปดาห์'].median() , inplace=True)
# /tmp/ipython-input-3580748940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_student
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ       GPA  ส่วนสูง(cm)  \
# 0          64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.210000        170.0
# 1          64002    สมหญิง  21.0  หญิง     วิทยาศาสตร์  3.450000        165.0
# 2          64003   ไม่ระบุ  21.0   ชาย     วิทยาศาสตร์  3.670000        175.0
# 3          64004  สมศักดิ์  22.0   ชาย     วิทยาศาสตร์  3.488125        168.0
# 4          64005      สมใจ  19.0  หญิง  วิศวกรรมศาสตร์  3.890000        160.0
# 6          64007     กิตติ  21.0  หญิง  วิศวกรรมศาสตร์  4.000000        158.0
# 7          64008      จิรา  20.0  หญิง      ศิลปศาสตร์  2.980000        180.0
# 8          64009    ชนาธิป  23.0   ชาย      ศิลปศาสตร์  3.340000        163.0
# 9          64010      ดารา  21.0  หญิง      ศิลปศาสตร์  3.560000        167.0
# 10         64011      ธีระ  21.0  หญิง     วิทยาศาสตร์  3.780000        167.5
# 11         64012       นภา  22.0   ชาย     วิทยาศาสตร์  3.488125        171.0
# ...
